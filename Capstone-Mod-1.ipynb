# %% [markdown]
# # Lone Wolf - Price Forecasting in Oil & Gas (Time Series)
#
# ## Data Engineering I: Cleaning data and converting data types
#
# ##------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder

# %%
# # Combine data sets to export to a single DF and clean the data

# combinedDf = pd.concat(
#     map(pd.read_csv, ["./time-series-test.csv", "./time-series-train.csv"]),axis=0, ignore_index=True)

# combinedDf.to_csv("./combined-dataset.csv")

# %%
timeSeriesDf = pd.read_csv("./combined-dataset.csv")

# %%
timeSeriesDf.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0              cty_name  iso3numeric   id  year  \
# 0             0           1  Syrian Arab Republic          760  SYR  2001
# 1             1           2        United Kingdom          826  GBR  1941
# 2             2           3           Philippines          608  PHL  1989
# 3             3           4       Kyrgyz Republic          417  KGZ  1944
# 4             4           5            Cape Verde          132  CPV  1988
#
#            eiacty  oil_prod32_14  oil_price_2000  oil_value_nom  ...  \
# 0           Syria     24100000.0        23.69800   4.318125e+09  ...
# 1  United Kingdom        30464.0        13.17518   2.545633e+05  ...
# 2     Philippines       267000.0        24.86816   3.567051e+07  ...
# 3      Kyrgyzstan            NaN        11.71031            NaN  ...
# 4      Cape Verde            0.0        21.41834   0.000000e+00  ...
#
#    net_gas_exports_value  net_gas_exports_valuePOP  \
# ...

# %%
timeSeriesDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15521 entries, 0 to 15520
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0.1                  15521 non-null  int64
#  1   Unnamed: 0                    15521 non-null  int64
#  2   cty_name                      15521 non-null  object
#  3   iso3numeric                   15521 non-null  int64
#  4   id                            15106 non-null  object
#  5   year                          15521 non-null  int64
#  6   eiacty                        14254 non-null  object
#  7   oil_prod32_14                 10103 non-null  float64
#  8   oil_price_2000                15503 non-null  float64
#  9   oil_value_nom                 10103 non-null  float64
#  10  oil_value_2000                10103 non-null  float64
#  11  oil_value_2014                10103 non-null  float64
# ...

# %%
# drop unwanted features

features2remove = ['Unnamed: 0.1','Unnamed: 0','id','eiacty','iso3numeric','oil_value_nom','oil_value_2000','oil_value_2014','gas_price_2000',
     'gas_value_nom','gas_value_2000','gas_value_2014','oil_gas_valuePOP_nom','oil_gas_valuePOP_2000','oil_gas_valuePOP_2014',
     'net_oil_exports_mt','net_oil_exports_value','net_oil_exports_valuePOP','net_gas_exports_bcf','net_gas_exports_mboe','net_gas_exports_value','net_gas_exports_valuePOP','mult_2000_2014','net_oil_gas_exports_valuePOP','oil_price_nom'
]

#len(timeSeriesDf['iso3numeric'].unique())
#len(timeSeriesDf['cty_name'].unique())

len(timeSeriesDf['mult_2000_2014'].unique())

cleanedDf = timeSeriesDf.drop(features2remove, axis=1, inplace=False)



for value in cleanedDf:
    print(value+" = ",len(cleanedDf[value].unique()))
# Out:
# cty_name =  187
# year =  83
# oil_prod32_14 =  4005
# oil_price_2000 =  92
# gas_prod55_14 =  3894
# gas_price_2000_mboe =  119
# gas_price_nom =  57
# oil_gas_value_nom =  5804
# oil_gas_value_2000 =  5836
# oil_gas_value_2014 =  5837
# oil_exports =  1805
# net_oil_exports =  2973
# gas_exports =  736
# population =  12454
# pop_maddison =  11324
# sovereign =  2
# mult_nom_2000 =  117
# mult_nom_2014 =  115

# %%
#one hot encoding

finalDF = pd.get_dummies(cleanedDf, columns=["cty_name"])

finalDF.describe()
# Out:
#                year  oil_prod32_14  oil_price_2000  gas_prod55_14  \
# count  15521.000000   1.010300e+04    15503.000000    8812.000000
# mean    1973.000000   1.834108e+07       26.513076     100.702009
# std       23.959069   6.384938e+07       21.459869     462.242415
# min     1932.000000   0.000000e+00        7.879107       0.000000
# 25%     1952.000000   0.000000e+00       11.710310       0.000000
# 50%     1973.000000   4.980000e+04       14.067980       0.000000
# 75%     1994.000000   4.025170e+06       36.535130      21.684397
# max     2014.000000   6.160000e+08       85.170708    5605.121816
#
#        gas_price_2000_mboe  gas_price_nom  oil_gas_value_nom  \
# count         1.552100e+04   15521.000000       1.023400e+04
# mean          1.403597e+07       1.448253       5.544579e+09
# std           1.102009e+07       1.869749       2.698006e+10
# min           0.000000e+00       0.050000       0.000000e+00
# 25%           0.000000e+00       0.080000       0.000000e+00
# ...

# %%
lable_df = finalDF['oil_price_2000']
features_df = finalDF.drop('oil_price_2000', axis=1, inplace=False)

# %%
lable_df.to_csv("./lable_df.csv")
features_df.to_csv("./features_df.csv")
